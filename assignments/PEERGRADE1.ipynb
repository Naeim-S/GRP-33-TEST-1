# %% [markdown]
# # Mandatory Assignment 1
#
# This is the first of two mandatory assignments which must be completed during the course. First some practical information:
#
# * When is the assignment due?: **23:59, Sunday, August 19, 2018.**
# * How do you grade the assignment?: You will **peergrade** each other as primary grading.
# * Can i work with my group?: **yes**
#
# The assigment consist of one to tree problems from each of the exercise sets you have solved so far (excluding set 1 and set 9). We've tried to select problems which are self contained, but it might be nessecary to solve some of the previous exercises in each set to fully answer the problems in this assignment.
#
# ## Problems from Exercise Set 2:
#
# > **Ex. 2.2**: Make two lists. The first should be numbered. The second should be unnumbered and contain at least one sublevel.

# %% [markdown]
# # [Answer to Ex. 2.2 here] (convert to markdown cell)
# 1. item 1
# - item 2
# - item 3
#
#
# - item 1
# - item 2
#     - item 2.1
#     - item 2.2
#         - item 2.2.1
# - item 3

# %% [markdown]
# ## Problems from Exercise set 3:
#
# > **Ex. 3.1.3:** Let `l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']`. Create from `l1` the sentence "Is r > g?" using your knowledge about string formatting. Make sure there is only one space in between worlds.
# >
# >> _Hint:_ You should be able to combine the above informations to solve this exercise.

# %%
# [Answer to Ex. 3.1.3 here]

l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']
del(l1[-3])

# Remove empty spaces after r and g
l1[0], l1[-2]= l1[0].strip(), l1[-2].strip()
# Swap positions of Is and r
a, b = l1.index('r'), l1.index('Is')
l1[a], l1[b] = l1[b], l1[a]

# Print solution
print(' '.join(l1[0:4])+l1[-1])
# Out:
# Is r > g?

# %% [markdown]
# > **Ex. 3.1.4**: Create an empty dictionary `words` using the `dict()`function. Then add each of the words in `['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']` as a key, with the value being a boolean indicator for whether the word begins with a vowel. The results should look like `{'bacon': False, 'asynchronous': True ...}`
# >
# >> _Hint:_ You might want co first construct a function that asseses whether a given word begins with a vowel or not.

# %%
# [Answer to Ex. 3.1.4 here]
words = dict()

keys = ['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']
values = []


i=0
while i < len(keys):
    if keys[i].startswith(('a','e','i','u','o')):
       values.append(True)
       i += 1
    else:
       values.append(False)
       i += 1
#print(values)

key_value_pairs = list(zip(keys, values))

words = dict(key_value_pairs)
print(words)


### OTHER WAY: via creating a function 
words = dict()
def first_vowel(word):
    if word[0] in 'aeiou':
        return True 
    else: 
        return False 

words = dict()

for key in keys:
    words[key] = first_vowel(key)
print(words)
# Out:
# {'animal': True, 'coffee': False, 'python': False, 'unit': True, 'knowledge': False, 'tread': False, 'arise': True}
# {'animal': True, 'coffee': False, 'python': False, 'unit': True, 'knowledge': False, 'tread': False, 'arise': True}

# %% [markdown]
# > **Ex. 3.3.2:** use the `requests` module (get it with `pip install requests`) and `construct_link()` to request birth data from the "FOD" table. Get all available years (variable "Tid"), but only female births (BARNKON=P) . Unpack the json payload and store the result. Wrap the whole thing in a function which takes an url as input and returns the corresponding output.
# >
# >> _Hint:_ The `requests.response` object has a `.json()` method.
# >
# >> _Note:_ you wrote `construct_link()` in 3.3.1, if you didn't heres the link you need to get: `https://api.statbank.dk/v1/data/FOLK1A/JSONSTAT?lang=en&Tid=*`

# %%
# [Answer to Ex. 3.3.2 here]
import requests

def construct_link(table_id, variables):
    base = 'https://api.statbank.dk/v1/data/{id}/JSONSTAT?lang=en'.format(id = table_id)
    
    for var in variables:
        base += '&{v}'.format(v = var)

    return base 


s1 = construct_link('FOD', ['Tid=*', 'BARNKON=P'])
girls = requests.get(s1)
data = girls.json()

data
# Out:
# {'dataset': {'dimension': {'BARNKON': {'label': 'sex of child',
#     'category': {'index': {'P': 0}, 'label': {'P': 'Girls'}}},
#    'ContentsCode': {'label': 'Indhold',
#     'category': {'index': {'FOD': 0},
#      'label': {'FOD': 'Live births'},
#      'unit': {'FOD': {'base': 'number', 'decimals': 0}}}},
#    'Tid': {'label': 'time',
#     'category': {'index': {'1973': 0,
#       '1974': 1,
#       '1975': 2,
#       '1976': 3,
#       '1977': 4,
#       '1978': 5,
#       '1979': 6,
#       '1980': 7,
#       '1981': 8,
#       '1982': 9,
#       '1983': 10,
#       '1984': 11,
#       '1985': 12,
#       '1986': 13,
#       '1987': 14,
#       '1988': 15,
#       '1989': 16,
#       '1990': 17,
#       '1991': 18,
#       '1992': 19,
#       '1993': 20,
#       '1994': 21,
#       '1995': 22,
#       '1996': 23,
#       '1997': 24,
#       '1998': 25,
#       '1999': 26,
#       '2000': 27,
#       '2001': 28,
#       '2002': 29,
#       '2003': 30,
#       '2004': 31,
# ...

# %% [markdown]
# ## Problems from exercise set 4

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# > **Ex. 4.1.1:** Use Pandas' CSV reader to fetch  daily data weather from 1864 for various stations - available [here](https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/).
# >
# >> *Hint 1*: for compressed files you may need to specify the keyword `compression`.
# >
# >> *Hint 2*: keyword `header` can be specified as the CSV has no column names.
# >
# >> *Hint 3*: Specify the path, as the URL linking directly to the 1864 file.

# %%
# [Answer to Ex. 4.1.1 here]
url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/1864.csv.gz'
df = pd.read_csv(url,compression='gzip', header=-1, sep=',')

print(df.head(3))
# Out:
#              0         1     2   3    4    5  6   7
# 0  ITE00100550  18640101  TMAX  10  NaN  NaN  E NaN
# 1  ITE00100550  18640101  TMIN -23  NaN  NaN  E NaN
# 2  ITE00100550  18640101  PRCP  25  NaN  NaN  E NaN

# %% [markdown]
# > **Ex. 4.1.2:** Structure your weather DataFrame by using only the relevant columns (station identifier, data, observation type, observation value), rename them. Make sure observations are correctly formated (how many decimals should we add? one?).
# >
# >> *Hint:* rename can be done with `df.columns=COLS` where `COLS` is a list of column names.

# %%
# [Answer to Ex. 4.1.2 here]
df = df.iloc[:,0:4]

df.columns = ['station_identifier', 'data', 'observation_type', 'observation_value']
print(df.head(3))

print(type(df[['data']]))

# "Make sure observations are correctly formated (how many decimals should we add? one?)." We do not know what is meant be that.
# For us all observations look fine, we do not understand what is referred to by adding decimals.
# Out:
#   station_identifier      data observation_type  observation_value
# 0        ITE00100550  18640101             TMAX                 10
# 1        ITE00100550  18640101             TMIN                -23
# 2        ITE00100550  18640101             PRCP                 25
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# > **Ex. 4.1.3:**  Select data for the station `ITE00100550` and only observations for maximal temperature. Make a copy of the DataFrame. Explain in a one or two sentences how copying works.
# >
# >> *Hint 1*: the `&` operator works elementwise on boolean series (like `and` in core python).
# >
# >> *Hint 2*: copying of the dataframe is done with the `copy` method for DataFrames.

# %%
# [Answer to Ex. 4.1.3 here]
df_select = df.copy()
df_select = df_select.loc[(df['station_identifier']=='ITE00100550') & (df['observation_type'] == 'TMAX')]
df_select
# Out:
#       station_identifier      data observation_type  observation_value
# 0            ITE00100550  18640101             TMAX                 10
# 75           ITE00100550  18640102             TMAX                  8
# 152          ITE00100550  18640103             TMAX                -28
# 227          ITE00100550  18640104             TMAX                  0
# 305          ITE00100550  18640105             TMAX                -19
# 383          ITE00100550  18640106             TMAX                -13
# 460          ITE00100550  18640107             TMAX                 -4
# 538          ITE00100550  18640108             TMAX                 13
# 618          ITE00100550  18640109             TMAX                 13
# 695          ITE00100550  18640110             TMAX                  6
# 770          ITE00100550  18640111             TMAX                -15
# 847          ITE00100550  18640112             TMAX                -25
# ...

# %% [markdown]
# > **Ex. 4.1.4:** Make a new column called `TMAX_F` where you have converted the temperature variables to Fahrenheit.
# >
# >> *Hint*: Conversion is $F = 32 + 1.8*C$ where $F$ is Fahrenheit and $C$ is Celsius.

# %%
# [Answer to Ex. 4.1.4 here]
df_select.apply(lambda row: 32+ 1.8 * row['observation_value'], axis=1)

df_select['TMAX_F'] = df_select.apply(lambda row: 32+ 1.8 * row['observation_value'], axis=1)
df_select
# Out:
#       station_identifier      data observation_type  observation_value  TMAX_F
# 0            ITE00100550  18640101             TMAX                 10    50.0
# 75           ITE00100550  18640102             TMAX                  8    46.4
# 152          ITE00100550  18640103             TMAX                -28   -18.4
# 227          ITE00100550  18640104             TMAX                  0    32.0
# 305          ITE00100550  18640105             TMAX                -19    -2.2
# 383          ITE00100550  18640106             TMAX                -13     8.6
# 460          ITE00100550  18640107             TMAX                 -4    24.8
# 538          ITE00100550  18640108             TMAX                 13    55.4
# 618          ITE00100550  18640109             TMAX                 13    55.4
# 695          ITE00100550  18640110             TMAX                  6    42.8
# 770          ITE00100550  18640111             TMAX                -15     5.0
# ...

# %% [markdown]
# ## Problems from exercise set 5

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns 

# %matplotlib inline 

iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')

# %% [markdown]
# > **Ex. 5.1.1:**: Show the first five rows of the titanic dataset. What information is in the dataset? Use a barplot to show the probability of survival for men and women within each passenger class. Can you make a boxplot showing the same information (why/why not?). _Bonus:_ show a boxplot for the fare-prices within each passenger class.
# >
# > Spend five minutes discussing what you can learn about the survival-selection aboard titanic from the figure(s).
# >
# > > _Hint:_ https://seaborn.pydata.org/generated/seaborn.barplot.html, specifically the `hue` option.

# %%
# [Answer to Ex. 5.1.1 here]
print(titanic.head(5))
f1= sns.barplot(x='pclass', y='survived', hue='sex', data=titanic)
plt.show()

#BOXPLOT??
f2= sns.boxplot(x='pclass', y='survived', hue='sex', data=titanic)
plt.show()
# We cannot show the same information with a boxplot as 'survived' is a categorical variable.
# Hence, a boxplot does not make sense.

f3= sns.boxplot(x='pclass', y='fare', data=titanic)
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# > **Ex. 5.1.2:** Using the iris flower dataset, draw a scatterplot of sepal length and petal length. Include a second order polynomial fitted to the data. Add a title to the plot and rename the axis labels.
# > _Discuss:_ Is this a meaningful way to display the data? What could we do differently?
# >
# > For a better understanding of the dataset this image might be useful:
# > <img src="iris_pic.png" alt="Drawing" style="width: 200px;"/>
# >
# >> _Hint:_ use the `.regplot` method from seaborn.

# %%
# [Answer to Ex. 5.1.2 here]
f4= sns.regplot(x='petal_length', y='sepal_length', data=iris, order=2)
f4.set_title('Flower Length')
f4.set_xlabel('Petal Length')
f4.set_ylabel('Sepal Length')

#DISCUSSION:
# We observe a increasing positive relationship between petal and sepal length.
# Hence, with increasing petal length, sepal length also increases (positive correlation).
# Maybe, we could use indexing to address the relationship between both length measurements:
# As you increase the petal length by 1% what is the marginal % change in sepal length?
# Go into more detail about the group of observations with low petal and sepal length (=setosa flowers) vs. 'the others'.
# Out:
# Text(0,0.5,'Sepal Length')

# %% [markdown]
# > **Ex. 5.1.3:** Combine the two of the figures you created above into a two-panel figure similar to the one shown here:
# > <img src="Example.png" alt="Drawing" style="width: 600px;"/>
# >
# > Save the figure as a png file on your computer.
# >> _Hint:_ See [this question](https://stackoverflow.com/questions/41384040/subplot-for-seaborn-boxplot) on stackoverflow for inspiration.

# %%
# [Answer to Ex. 5.1.3 here]
f, axes = plt.subplots(1, 2)

sns.barplot(x='pclass', y='survived', hue='sex', data=titanic,  ax=axes[0])
f3 = sns.regplot(x='petal_length', y='sepal_length', data=iris, order=2, ax=axes[1])
f3.set_title('Flower Length')
f3.set_xlabel('Sepal Length')
f3.set_ylabel('Petal Length')

f.savefig('Fig1.png')

# %% [markdown]
# > **Ex. 5.1.4:** Use [pairplot with hue](https://seaborn.pydata.org/generated/seaborn.pairplot.html) to create a figure that clearly shows how the different species vary across measurements. Change the color palette and remove the shading from the density plots. _Bonus:_ Try to explain how the `diag_kws` argument works (_hint:_ [read here](https://stackoverflow.com/questions/1769403/understanding-kwargs-in-python))

# %%
# [Answer to Ex. 5.1.4 here]
sns.pairplot(data=iris, hue='species', hue_order=None, palette='husl', diag_kind='kde', markers=['o', 's', 'D'])

# %% [markdown]
# ## Problems from exercise set 6
#
# > _Note:_ A central part of these exercises and the ones from exercise set 7 is downloading data from the NOAA servers. If you cannot complete this part, you can download the data as csv files **from [github](https://github.com/abjer/sds/tree/master/material/session_7)**.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# > **Ex. 6.1.4:** Extract the country code from the station name into a separate column.
# >
# >> _Hint:_ The station column contains a GHCND ID, given to each weather station by NOAA. The format of these ID's is a 2-3 letter country code, followed by a integer identifying the specific station. A simple approach is to assume a fixed length of the country ID. A more complex way would be to use the [`re`](https://docs.python.org/2/library/re.html) module.

# %%
# [Answer to Ex. 6.1.4]
# Country code will be generated as part of the fct. for the next question.

# %% [markdown]
# > **Ex. 6.1.5:** Make a function that downloads and formats the weather data according to previous exercises in Exercise Section 4.1, 6.1. You should use data for ALL stations but still only select maximal temperature. _Bonus:_ To validate that your function works plot the temperature curve for each country in the same window. Use `plt.legend()` to add a legend.

# %%
# [Answer to Ex. 6.1.5]
year = '1864'

def get_weather(year):
    # Construct URL
    url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/'+year+'.csv.gz'
    # Load data
    df_weather = pd.read_csv(url,
                         compression='gzip',
                         header=None).iloc[:,:4]
    # Select columns
    df_weather.columns = ['station', 'datetime', 'obs_type', 'obs_value']
    df_weather['obs_value'] = df_weather['obs_value'] / 10
    # Generate column with temperatur in Fahrenheit
    df_select = df_weather[(df_weather.obs_type == 'TMAX')].copy()
    df_select['TMAX_F'] = 32 + 1.8 * df_select['obs_value']
    # Sort data set
    df_sorted = df_select.reset_index(drop=True).sort_values(by=['obs_value'])
    # Transform date variable
    df_sorted['datetime']=df_sorted['datetime'].astype(str)
    df_sorted['datetime'] = pd.to_datetime(df_sorted['datetime'])
    # Create variable for month
    df_sorted['month']=df_sorted['datetime'].dt.month
    # Create variable for country code
    df_sorted['country']=df_sorted['station'].str[0:3]
    return df_sorted

df = get_weather(year)
df
# Out:
#           station   datetime obs_type  obs_value  TMAX_F  month country
# 845   SZ000006717 1864-02-26     TMAX      -34.0  -29.20      2     SZ0
# 577   SZ000006717 1864-02-08     TMAX      -17.4    0.68      2     SZ0
# 699   CA006158350 1864-02-17     TMAX      -16.7    1.94      2     CA0
# 42    SZ000006717 1864-01-03     TMAX      -16.5    2.30      1     SZ0
# 16    CA006158350 1864-01-02     TMAX      -16.1    3.02      1     CA0
# 607   SZ000006717 1864-02-10     TMAX      -15.9    3.38      2     SZ0
# 199   EZE00100082 1864-01-14     TMAX      -15.1    4.82      1     EZE
# 592   SZ000006717 1864-02-09     TMAX      -15.0    5.00      2     SZ0
# 741   SZ000006717 1864-02-19     TMAX      -14.7    5.54      2     SZ0
# 533   SZ000006717 1864-02-05     TMAX      -14.4    6.08      2     SZ0
# 756   SZ000006717 1864-02-20     TMAX      -14.2    6.44      2     SZ0
# 229   EZE00100082 1864-01-16     TMAX      -14.2    6.44      1     EZE
# ...

# %% [markdown]
# ## Problems from exercise set 7
#
# > _Note:_ Once again if you haven't managed to download the data from NOAA, you can refer to the github repo to get csv-files containing the required data.

# %%
# %matplotlib inline 

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl

# Increases the plot size a little
mpl.rcParams['figure.figsize'] = 11, 6

# %% [markdown]
# > **Ex. 7.1.1:** Plot the monthly max,min, mean, first and third quartiles for maximum temperature for our station with the ID _'ITE00100550'_ in 1864.
#
# > *Hint*: the method `describe` computes all these measures.

# %%
# [Answer to Ex. 7.1.1]
split_vars = ['station', 'month']
apply_vars = ['TMAX_F']

combined = df\
    .groupby(split_vars)\
    [apply_vars]\
    .describe()

#print(combined.reset_index().head(5))

stats = combined.reset_index()

#print(stats['TMAX_F']['mean'].head(5))

fig, ax = plt.subplots(figsize = (10, 4.5))
ax.set_xlim([1, 12]) # x-axis cutoffs 
ax.set_ylim([0, 100]) # y-axis cutoffs


for i in ['min', '25%', '75%', 'max', 'mean']:
    stats[stats['station']=='ITE00100550'].set_index('month').TMAX_F[i].plot(label=str(i))
plt.legend()

# %% [markdown]
# > **Ex. 7.1.2:** Get the processed data from years 1864-1867 as a list of DataFrames. Convert the list into a single DataFrame by concatenating vertically.

# %%
# [Answer to Ex. 7.1.2]
df_list = []

for y in ['1864', '1865', '1866', '1867']:
    df = get_weather(y)
    df_list.append(df)

print(pd.concat(df_list))
# Out:
#           station   datetime obs_type  obs_value  TMAX_F  month country
# 845   SZ000006717 1864-02-26     TMAX      -34.0  -29.20      2     SZ0
# 577   SZ000006717 1864-02-08     TMAX      -17.4    0.68      2     SZ0
# 699   CA006158350 1864-02-17     TMAX      -16.7    1.94      2     CA0
# 42    SZ000006717 1864-01-03     TMAX      -16.5    2.30      1     SZ0
# 16    CA006158350 1864-01-02     TMAX      -16.1    3.02      1     CA0
# 607   SZ000006717 1864-02-10     TMAX      -15.9    3.38      2     SZ0
# 199   EZE00100082 1864-01-14     TMAX      -15.1    4.82      1     EZE
# 592   SZ000006717 1864-02-09     TMAX      -15.0    5.00      2     SZ0
# 741   SZ000006717 1864-02-19     TMAX      -14.7    5.54      2     SZ0
# 533   SZ000006717 1864-02-05     TMAX      -14.4    6.08      2     SZ0
# 756   SZ000006717 1864-02-20     TMAX      -14.2    6.44      2     SZ0
# 229   EZE00100082 1864-01-16     TMAX      -14.2    6.44      1     EZE
# ...

# %% [markdown]
# > **Ex. 7.1.3:** Parse the station location data which you can find at https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt. Merge station locations onto the weather data spanning 1864-1867.
#
# > _Hint:_ The location data have the folllowing format,
#
# ```
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------
# ```
#
# > *Hint*: The station information has fixed width format - does there exist a pandas reader for that?

# %%
# [Answer to Ex. 7.1.3]
import pandas as pd
head = ['ID', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'STATE', 'NAME', 'GSN FLAG', 'HCN/CRN FLAG', 'WMO ID']

url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt'

df = pd.read_fwf(url, names = head)

print(df.head())
# Out:
#             ID  LATITUDE  LONGITUDE  ELEVATION                  STATE NAME  \
# 0  ACW00011604   17.1167   -61.7833       10.1  ST JOHNS COOLIDGE FLD  NaN
# 1  ACW00011647   17.1333   -61.7833       19.2               ST JOHNS  NaN
# 2  AE000041196   25.3330    55.5170       34.0    SHARJAH INTER. AIRP  NaN
# 3  AEM00041194   25.2550    55.3640       10.4             DUBAI INTL  NaN
# 4  AEM00041217   24.4330    54.6510       26.8         ABU DHABI INTL  NaN
#
#   GSN FLAG  HCN/CRN FLAG  WMO ID
# 0      NaN           NaN     NaN
# 1      NaN           NaN     NaN
# 2      GSN       41196.0     NaN
# 3      NaN       41194.0     NaN
# 4      NaN       41217.0     NaN

# %% [markdown]
# ## Problems from exercise set 8
#
# > **Ex. 8.1.2.:** Use the `request` module to collect the first page of job postings and unpack the relevant `json` data into a `pandas` DataFrame.

# %%
# [Answer to Ex. 8.1.2]
import requests
import pandas as pd
import json
url = 'https://job.jobnet.dk/CV/FindWork/Search'
response = requests.get(url)
response.ok

d = requests.get(url).json()
d.keys()

df= pd.DataFrame(d['JobPositionPostings'])
df
# Out:
#     AnonymousEmployer  AssignmentStartDate  AutomatchType  Country  \
# 0               False  0001-01-01T00:00:00              0  Danmark
# 1               False  0001-01-01T00:00:00              0  Danmark
# 2               False  0001-01-01T00:00:00              0  Danmark
# 3               False  0001-01-01T00:00:00              0  Danmark
# 4               False  0001-01-01T00:00:00              0  Danmark
# 5               False  0001-01-01T00:00:00              0  Danmark
# 6               False  0001-01-01T00:00:00              0  Danmark
# 7               False  0001-01-01T00:00:00              0  Danmark
# 8               False  0001-01-01T00:00:00              0  Danmark
# 9               False  0001-01-01T00:00:00              0  Danmark
# 10              False  0001-01-01T00:00:00              0  Danmark
# 11              False  0001-01-01T00:00:00              0  Danmark
# 12              False  0001-01-01T00:00:00              0  Danmark
# ...

# %% [markdown]
# > **Ex. 8.1.3.:** Store and print the 'TotalResultCount' value for later use. Also create a dataframe from the 'JobPositionPostings' field in the json.

# %%
# [Answer to Ex. 8.1.3]
total_count = d['TotalResultCount']
print(total_count)

# As before...
df = pd.DataFrame.from_dict(d[ 'JobPositionPostings'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-68547d3818be> in <module>()
#       1 # [Answer to Ex. 8.1.3]
# ----> 2 total_count = d['TotalResultCount']
#       3 print(total_count)
#       4
#       5 # As before...
#
# NameError: name 'd' is not defined

# %% [markdown]
# ## Problems from exercise set 9
#
# > **Ex. 9.2.1:** Load the data used in the exercise using the `pd.read_csv` function. (Hint: path to file can be both a url or systempath).
#
# >Define a variable `sample_string = '\n'.join(df.sample(2000).reviewBody)` as sample of all the reviews that you will practice on.  (Run it once in a while to get a new sample for potential differences).
# Imagine we were a company wanting to find the reviews where customers are concerned with the price of a service. They decide to write a regular expression to match all reviews where a currencies and an amount is mentioned.

# %%
# [Answer to Ex. 9.2.1]

import requests

url = 'https://raw.githubusercontent.com/snorreralund/scraping_seminar/master/english_review_sample.csv'
df = pd.read_csv(url)
sample_string = '\n'.join(df.sample(2000).reviewBody)

# %% [markdown]
# > **Ex. 9.2.2:**
# > Write an expression that matches both the dollar-sign (\$) and dollar written literally, and the amount before or after a dollar-sign. Remember that the "$"-sign is a special character in regular expressions. Explore and refine using the explore_pattern function in the package I created called explore_regex.
# ```python
# import explore_regex as e_re
# explore_regex = e_re.Explore_Regex(sample_string) # Initaizlie the Explore regex Class.
# explore_regex.explore_pattern(pattern) # Use the .explore_pattern method.
# ```
#
#
# Start with exploring the context around digits ("\d") in the data.

# %%
# [Answer to Ex. 9.2.2]

# Load explore_regex
import requests
url = 'https://raw.githubusercontent.com/snorreralund/explore_regex/master/explore_regex.py'
response = requests.get(url)
with open('explore_regex.py','w') as f:
    f.write(response.text)
import explore_regex as e_re


explore_regex = e_re.ExploreRegex(sample_string) # Initaizlie the Explore regex Class.
first = '\d+\$'
second = '\d+ dollar'
third = '\$+\d'

patterns = [first, second, third]


explore_regex.explore_pattern(first) # Use the .explore_pattern method.
explore_regex.explore_pattern(second)
explore_regex.explore_pattern(third)
# Out:
# ------ Pattern: \d+\$	 Matched 2 patterns -----
# Match: 850$	Context:delivery (850$), today i
# Match: 274$	Context:oice said 274$ but my cr
# ------ Pattern: \d+ dollar	 Matched 3 patterns -----
# Match: 54 dollar	Context: total is 54 dollars and some
# Match: 10 dollar	Context: gave the 10 dollar boots a s
# Match: 2000 dollar	Context:re saving 2000 dollars in the l
# ------ Pattern: \$+\d	 Matched 68 patterns -----
# Match: $9	Context:1. So for $9.99 it was
# Match: $5	Context:o give me $5 off my ne
# Match: $2	Context:give me a $20 credit!
# Match: $1	Context: got some $1 used book
# Match: $7	Context: card for $75.00 vice
# Match: $3	Context: For the ~$30 or so we
# Match: $8	Context:ve I paid $8 for regul
# Match: $5	Context:ns.
# Got a $5.00 credit
# Match: $2	Context: food for $20 less a b
# Match: $3	Context:h a price $30 cheaper

# %% [markdown]
# > **Ex.9.2.3** Use the .report() method. e_re.report(), and print the all patterns in the development process using the .pattern method - i.e. e_re.patterns

# %%
# [Answer to Ex. 9.2.3]

print(explore_regex.patterns[0],explore_regex.patterns[1],explore_regex.patterns[2])


explore_regex.report('hard')
explore_regex.report('soft')

# We are not sure we understand the question correctly. :(
# Out:
# \d+\$ \d+ dollar \$+\d
# ------ Pattern: \d+\$	 Matched 2 patterns -----
# ------ Pattern: \d+ dollar	 Matched 3 patterns -----
# ------ Pattern: \$+\d	 Matched 68 patterns -----
# ------ Pattern: \d+\$	 Matched 2 patterns -----
# ------ Pattern: \d+ dollar	 Matched 3 patterns -----
# ------ Pattern: \$+\d	 Matched 68 patterns -----
