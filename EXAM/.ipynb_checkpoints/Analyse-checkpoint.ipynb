# %% [markdown]
# # Analyse

# %%
import pandas as pd
import time, requests, re
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.style.use('ggplot')
# sns.set_style("whitegrid", {'axes.grid' : True})

# %%
path = "C:/Users/Naeim.S/Documents/GitHub/GRP33/EXAM/Multi_JobIndexed.xlsx"
# cols = list(range(1,9))
jobindexed = pd.read_excel(path)
jobindexed
# Out:
#         year                area        sektor               jobtype  \
# 0     2007.0  region hovedstaden        handel         boernepasning
# 1        NaN                 NaN           NaN                   bud
# 2        NaN                 NaN           NaN          detailhandel
# 3        NaN                 NaN           NaN               frisoer
# 4        NaN                 NaN           NaN                 hotel
# 5        NaN                 NaN           NaN            rengoering
# 6        NaN                 NaN           NaN               service
# 7        NaN                 NaN           NaN             sikkerhed
# 8        NaN                 NaN      industri                  blik
# 9        NaN                 NaN           NaN               byggeri
# 10       NaN                 NaN           NaN            elektriker
# 11       NaN                 NaN           NaN              industri
# 12       NaN                 NaN           NaN                  jern
# ...

# %%
#Creating the First-Differences by each group:
# jobindexed.FD_area = jobindexed.n_area.groupby(level=[0,1]).diff()
jobindexed["FD_area"] = jobindexed["n_area"].groupby(level=["jobtype"]).diff(1)
jobindexed[["n_area", "FD_area"]].query("jobtype == 'database'")
# Out:
#                                          n_area   FD_area
# year area               sektor jobtype
# 2007 region hovedstaden it     database  157867       NaN
#      region syddanmark  it     database   78473  -79394.0
#      region-midtjylland it     database   80746    2273.0
#      region-nordjylland it     database   26736  -54010.0
#      region-sjaelland   it     database   38163   11427.0
# 2008 region hovedstaden it     database  129930   91767.0
#      region syddanmark  it     database   60879  -69051.0
#      region-midtjylland it     database   66756    5877.0
#      region-nordjylland it     database   23530  -43226.0
#      region-sjaelland   it     database   32955    9425.0
# 2009 region hovedstaden it     database   68902   35947.0
#      region syddanmark  it     database   31271  -37631.0
#      region-midtjylland it     database   35370    4099.0
#      region-nordjylland it     database   12958  -22412.0
# ...

# %%
jobindexed.xs(key="laege", level=3)
# Out:
#                                 n_jobtype_area_  n_sektor_area  n_area  \
# year area               sektor
# 2007 region hovedstaden social             2018          18193  157867
#      region syddanmark  social             1023          12128   78473
#      region-midtjylland social             1059          12003   80746
#      region-nordjylland social              376           4551   26736
#      region-sjaelland   social              587           6491   38163
# 2008 region hovedstaden social             1538          15023  129930
#      region syddanmark  social              858           9974   60879
#      region-midtjylland social              918          10432   66756
#      region-nordjylland social              388           4483   23530
#      region-sjaelland   social              801           7308   32955
# 2009 region hovedstaden social             1376          10537   68902
#      region syddanmark  social              865           6734   31271
# ...
