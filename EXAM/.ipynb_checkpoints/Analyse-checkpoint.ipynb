# %% [markdown]
# # Analyse

# %%
import pandas as pd
import time, requests, re
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.style.use('ggplot')
# sns.set_style("whitegrid", {'axes.grid' : True})

# %%
#The data with the first differences is loaded
path = "https://github.com/Naeim-S/GRP33/blob/master/EXAM/Multi_JobIndexed.xlsx?raw=true"
jobindexed = pd.read_excel(path)
#Multi indexing will be done after merging:
# jobindexed = jobindexed.set_index(['year', 'area', 'sektor', 'jobtype']).sort_index()
jobindexed.tail(10)

# %%
#Load the BNP data from DST:
import requests

def get_data(table_id,variables):
    base = 'https://api.statbank.dk/v1/data/{id}/JSONSTAT?lang=en'.format(id = table_id)
    
    for var in variables:
        base += '&{v}'.format(v = var) 

    response=requests.get(base)
    data_json=response.json()
    return data_json

indexlabels_bnp=[2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
data_bnp=get_data('NAN1',['Tid=2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017','TRANSAKT=B1GQK','PRISENHED=LAN_M']) # Nordjylland
BNP=pd.DataFrame(data_bnp['dataset']['value'],index=indexlabels_bnp,columns=['BNP, 1000 kr. (2010)'])
# BNP=BNP.reindex(labels = ['year'], index=BNP.index[::-1]).sort_index()
# BNP=BNP.transpose()
BNP.index.names = ['year']
BNP["FD_BNP"] = BNP.diff(1)
BNP["RFD_BNP"] = BNP.diff()
BNP
# Out:
#       BNP, 1000 kr. (2010)     FD_BNP
# year
# 2007           1879.008892        NaN
# 2008           1869.388052  -9.620840
# 2009           1777.665635 -91.722417
# 2010           1810.925601  33.259966
# 2011           1835.133652  24.208051
# 2012           1839.290226   4.156574
# 2013           1856.457075  17.166849
# 2014           1886.520426  30.063351
# 2015           1916.828880  30.308454
# 2016           1954.476749  37.647869
# 2017           1998.975791  44.499042

# %%
#Merge the JobIndex data with the BNP:
merged = pd.merge(jobindexed, BNP, on="year", how="left", validate="m:1")
#Create the multi index:
# merged = merged.set_index(['year', 'area', 'sektor', 'jobtype']).sort_index()
merged.query('year == 2009').tail(10) #Looks beautiful
# Out:
#       year              area        sektor            jobtype  n_jobtype_area  \
# 1340  2009  region-sjaelland        social              pleje            1285
# 1341  2009  region-sjaelland        social          psykologi             150
# 1342  2009  region-sjaelland        social  socialraadgivning             423
# 1343  2009  region-sjaelland        social          tandlaege              89
# 1344  2009  region-sjaelland        social     teknisksundhed              80
# 1345  2009  region-sjaelland        social             terapi             252
# 1346  2009  region-sjaelland  undervisning          bibliotek              41
# 1347  2009  region-sjaelland  undervisning          forskning             269
# 1348  2009  region-sjaelland  undervisning             laerer             895
# 1349  2009  region-sjaelland  undervisning           paedagog            2074
#
#       n_sektor_area  n_sektor  n_area  n_year  20-64years_area    ...      \
# 1340           4492     32775   16937  167084           473460    ...
# 1341           4492     32775   16937  167084           473460    ...
# 1342           4492     32775   16937  167084           473460    ...
# 1343           4492     32775   16937  167084           473460    ...
# 1344           4492     32775   16937  167084           473460    ...
# 1345           4492     32775   16937  167084           473460    ...
# 1346           3621     31884   16937  167084           473460    ...
# 1347           3621     31884   16937  167084           473460    ...
# 1348           3621     31884   16937  167084           473460    ...
# 1349           3621     31884   16937  167084           473460    ...
#
#       n_sektor_area_pc  n_area_pc  n_year_pc  FD_jobtype_area  FD_sektor_area  \
# 1340          0.009488   0.035773   0.050891           -957.0         -2816.0
# 1341          0.009488   0.035773   0.050891            -92.0         -2816.0
# 1342          0.009488   0.035773   0.050891            -67.0         -2816.0
# 1343          0.009488   0.035773   0.050891            -94.0         -2816.0
# 1344          0.009488   0.035773   0.050891            -35.0         -2816.0
# 1345          0.009488   0.035773   0.050891           -142.0         -2816.0
# 1346          0.007648   0.035773   0.050891             -7.0         -2260.0
# 1347          0.007648   0.035773   0.050891            -94.0         -2260.0
# 1348          0.007648   0.035773   0.050891           -663.0         -2260.0
# 1349          0.007648   0.035773   0.050891          -1427.0         -2260.0
#
#       FD_sektor  FD_area   FD_year  BNP, 1000 kr. (2010)     FD_BNP
# 1340   -14727.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1341   -14727.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1342   -14727.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1343   -14727.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1344   -14727.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1345   -14727.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1346   -14276.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1347   -14276.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1348   -14276.0 -16018.0 -145823.0           1777.665635 -91.722417
# 1349   -14276.0 -16018.0 -145823.0           1777.665635 -91.722417
#
# [10 rows x 22 columns]

# %%
#Creating the ratio variables:
merged["ratio_jobtype_area"] = merged["FD_jobtype_area"] / merged["FD_BNP"]
merged["ratio_sektor_area"] = merged["FD_sektor_area"] / merged["FD_BNP"]
merged["ratio_sektor"] = merged["FD_sektor"] / merged["FD_BNP"]
merged["ratio_area"] = merged["FD_area"] / merged["FD_BNP"]
merged["ratio_year"] = merged["FD_year"] / merged["FD_BNP"]
merged.to_csv("merged_ratio.csv") #Saved as a back up, just in case.
merged.head(10) #What a lovely sight
# Out:
#    year                area    sektor        jobtype  n_jobtype_area  \
# 0  2007  region hovedstaden    handel  boernepasning             234
# 1  2007  region hovedstaden    handel            bud            1097
# 2  2007  region hovedstaden    handel   detailhandel           15574
# 3  2007  region hovedstaden    handel        frisoer             335
# 4  2007  region hovedstaden    handel          hotel            6901
# 5  2007  region hovedstaden    handel     rengoering            2985
# 6  2007  region hovedstaden    handel        service            1790
# 7  2007  region hovedstaden    handel      sikkerhed             580
# 8  2007  region hovedstaden  industri           blik             867
# 9  2007  region hovedstaden  industri        byggeri            1493
#
#    n_sektor_area  n_sektor  n_area  n_year  20-64years_area     ...      \
# 0          29369     78377  157867  380597          1021591     ...
# 1          29369     78377  157867  380597          1021591     ...
# 2          29369     78377  157867  380597          1021591     ...
# 3          29369     78377  157867  380597          1021591     ...
# 4          29369     78377  157867  380597          1021591     ...
# 5          29369     78377  157867  380597          1021591     ...
# 6          29369     78377  157867  380597          1021591     ...
# 7          29369     78377  157867  380597          1021591     ...
# 8          16285     61768  157867  380597          1021591     ...
# 9          16285     61768  157867  380597          1021591     ...
#
#    FD_sektor  FD_area  FD_year  BNP, 1000 kr. (2010)  FD_BNP  \
# 0        NaN      NaN      NaN           1879.008892     NaN
# 1        NaN      NaN      NaN           1879.008892     NaN
# 2        NaN      NaN      NaN           1879.008892     NaN
# 3        NaN      NaN      NaN           1879.008892     NaN
# 4        NaN      NaN      NaN           1879.008892     NaN
# 5        NaN      NaN      NaN           1879.008892     NaN
# 6        NaN      NaN      NaN           1879.008892     NaN
# 7        NaN      NaN      NaN           1879.008892     NaN
# 8        NaN      NaN      NaN           1879.008892     NaN
# 9        NaN      NaN      NaN           1879.008892     NaN
#
#    ratio_jobtype_area  ratio_sektor_area  ratio_sektor  ratio_area  ratio_year
# 0                 NaN                NaN           NaN         NaN         NaN
# 1                 NaN                NaN           NaN         NaN         NaN
# 2                 NaN                NaN           NaN         NaN         NaN
# 3                 NaN                NaN           NaN         NaN         NaN
# 4                 NaN                NaN           NaN         NaN         NaN
# 5                 NaN                NaN           NaN         NaN         NaN
# 6                 NaN                NaN           NaN         NaN         NaN
# 7                 NaN                NaN           NaN         NaN         NaN
# 8                 NaN                NaN           NaN         NaN         NaN
# 9                 NaN                NaN           NaN         NaN         NaN
#
# [10 rows x 27 columns]

# %%
merged2017 = merged.query('year == 2017')
sns.set_palette("tab10")
sns.catplot(x='sektor', y="ratio_sektor_area", 
            kind="bar", 
            hue="area",
            height = 7,
            aspect= 1.5,
            data=merged2017)

# %%
merged2008 = merged.query('year == 2008')
sns.set_palette("tab10")
sns.catplot(x='sektor', y="ratio_sektor_area", 
            kind="bar", 
            hue="area",
            height = 7,
            aspect= 1.5,
            data=merged2008)

# %%
merged2009 = merged.query('year == 2009')
sns.set_palette("tab10")
sns.catplot(x='sektor', y="ratio_sektor_area", 
            kind="bar", 
            hue="area",
            height = 7,
            aspect= 1.5,
            data=merged2009)

# %%
sns.catplot(x='jobtype', y="ratio_jobtype_area", 
            kind="bar", 
            hue="area",
            height = 7,
            aspect= 1.5,
            data=merged2017.query('sektor == "oevrige"'))

# %%
sns.relplot(x='year', y="ratio_sektor", 
            kind="line", 
            hue="sektor",
            height = 7,
            aspect= 1.5,
            data=merged)
