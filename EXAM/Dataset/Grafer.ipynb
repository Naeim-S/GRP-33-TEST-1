# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns 

contest = pd.read_csv('final-Copy1.csv')

# %%
contest
# Out:
#        Unnamed: 0    år          område        sektor               jobtype  \
# 0               0  2007  storkoebenhavn            it              database
# 1               1  2007  storkoebenhavn            it               itdrift
# 2               2  2007  storkoebenhavn            it              itkurser
# 3               3  2007  storkoebenhavn            it             itledelse
# 4               4  2007  storkoebenhavn            it              internet
# 5               5  2007  storkoebenhavn            it       systemudvikling
# 6               6  2007  storkoebenhavn            it               telekom
# 7               7  2007  storkoebenhavn            it   virksomhedssystemer
# 8               8  2007  storkoebenhavn     ingenioer           byggeteknik
# 9               9  2007  storkoebenhavn     ingenioer            elektronik
# 10             10  2007  storkoebenhavn     ingenioer                  kemi
# ...

# %%
# Grafer:

# %%
IT = sns.barplot(y='jobtype', x='år', data=contest, hue='sektor')
# regplotiris.set_title('Title')
# regplotiris.set_ylabel('petal')
# regplotiris.set_xlabel('sepal')

# %%
sektorit = contest.loc[contest['sektor'] == 'it']
year = sektorit['år']
sektorsocial = contest.loc[contest['sektor'] == 'social']


plt.plot(year, sektorit['numbers'], color='g')
plt.plot(year, sektorsocial['numbers'], color='orange')

plt.show()
