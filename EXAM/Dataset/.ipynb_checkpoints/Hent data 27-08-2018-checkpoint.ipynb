# %%
# Hey, vi skal alle sammen køre den første celle. Derudover skal vi hver 
# køre én celle. Jeg har skrevet navn øverst i hver celle :D
# Bare lad koden køre, den gemmer selv i gruppen når den er færdig. 
# Krydser fingre

# %%
# Alle kører denne:

import pandas as pd
import time, requests, re
from bs4 import BeautifulSoup

sektor = {"it":["database", "itdrift", "itkurser", "itledelse",
                "internet", "systemudvikling", "telekom", "virksomhedssystemer"],
         "ingenioer":["byggeteknik", "elektronik", "kemi", "teknikledelse",  
                     "maskiningenioer", "medicinal", "produktionsteknik"],
         "ledelse":["detailledelse", "freelancekonsulent", "hrkurser", "itledelse",
                   "institutions", "leder", "teknikledelse", "personale", "projektledelse",
                   "salgschef", "topledelse", "virksomhedsudvikling", "oekonomichef"],
         "handel": ["bud", "boernepasning", "detailhandel", "ejendomsservice",
                    "frisoer", "hotel", "rengoering", "service", "sikkerhed"],
         "industri": ["blik", "byggeri", "elektriker", "industri", "jern", "lager", "landbrug",
                     "maling", "mekanik", "naeringsmiddel", "tekstil", "transport", "traeindustri",
                     "toemrer"],
         "salg": ["design", "ejendomsmaegler", "grafisk", "kommunikation", "kultur", "marketing",
                  "salg", "salgskurser", "franchise", "telemarketing"],
         "undervisning": ["bibliotek", "forskning", "laerer", "paedagog", "voksenuddannelser"],
         "kontor": ["akademisk", "ejendomsmaegler", "ejendomsservice", "finans", "indkoeb",
                   "jura", "kontor", "kontorkurser", "kontorelev", "logistik", "offentlig",
                   "oversaettelse", "sekretaer", "oekonomi"],
         "social": ["laege", "laegesekretaer", "pleje", "psykologi", "socialraadgivning",
                    "sygeplejske", "tandlaege", "teknisksundhed", "terapi"],
         "oevrige": ["elev", "forsvar", "frivilligt", "student", "studiepraktik", "oevrige", "kurseroevrige"]}
område = ["storkoebenhavn", "nordsjaelland", "region-sjaelland", \
          "fyn", "region-nordjylland", "region-midtjylland", \
         "sydjylland", "bornholm", "skaane", "groenland", "faeroeerne" \
         "udlandet", "danmark"]

# Test: 
# sektor = {"it":["database", "itdrift", "itkurser", "itledelse",
#                 "internet", "systemudvikling", "telekom", "virksomhedssystemer"],
#          "ingenioer":["byggeteknik", "elektronik", "kemi", "teknikledelse",  
#                      "maskiningenioer", "medicinal", "produktionsteknik"],
#          "ledelse":["detailledelse", "freelancekonsulent", "hrkurser", "itledelse",
#                    "institutions", "leder", "teknikledelse", "personale", "projektledelse",
#                    "salgschef", "topledelse", "virksomhedsudvikling", "oekonomichef"]}
          
# område = ["storkoebenhavn", "nordsjaelland", "region-sjaelland"]



# Generér funktioner
    # n_jobtype_område
def NJO(sektor, jobtype, område, år):
    url1 = 'https://www.jobindex.dk/jobsoegning/'
    url2 = '/?jobage=archive&maxdate='
    url3 = '1231&mindate='
    url4 = '0101'
    return url1 + str(sektor) + '/' + str(jobtype) + '/' + str(område) + url2 + str(år) + url3 + str(år) + url4

    # n_sektor_område
def NSO(sektor, område, år):
    url1 = 'https://www.jobindex.dk/jobsoegning/'
    url2 = '/?jobage=archive&maxdate='
    url3 = '1231&mindate='
    url4 = '0101'
    return url1 + str(sektor) + '/' + str(område) + url2 + str(år) + url3 + str(år) + url4

    # n_sektor
def NS(sektor, år):
    url1 = 'https://www.jobindex.dk/jobsoegning/'
    url2 = '?jobage=archive&maxdate='
    url3 = '1231&mindate='
    url4 = '0101'
    return url1 + str(sektor) + url2 + str(år) + url3 + str(år) + url4

    # n_område
def NO_(område, år):
    url1 = 'https://www.jobindex.dk/jobsoegning/'
    url2 = '?jobage=archive&maxdate='
    url3 = '1231&mindate='
    url4 = '0101'
    return url1 + str(område) + url2 + str(år) + url3 + str(år) + url4

    # n_år
def NÅ(år):
    url1 = 'https://www.jobindex.dk/jobsoegning?maxdate='
    url2 = '1231&mindate='
    url3 = '0101&jobage=archive'
    return url1 + str(år) + url2 + str(år) + url3

# %%
# Kode til Naeim: 

år = [2007, 2008, 2009]

n_jobtype_område_ = []
n_sektor_område_ = []
n_område_ = []
n_år_ = []

jobt_ = []
sektor_ = []
område_ = []
år_ = []


# Running loop:

for z in år:
# n_år:  brug for år
    urlNÅ = NÅ(z)

    responseNÅ = requests.get(urlNÅ)
    htmlNÅ = responseNÅ.text
    jobindexNÅ = BeautifulSoup(htmlNÅ,'lxml')


    tal1NÅ = str(jobindexNÅ.find('h2'))
    if """<h2 class="search-title">""" in tal1NÅ:
        tal2NÅ = re.sub("""<h2 class="search-title">""", '', tal1NÅ)
        tal3NÅ = re.sub(""" job matcher din søgning</h2>""", '', tal2NÅ)
        tal4NÅ = int(tal3NÅ.replace('.',''))

        for x in område:
# n_område:  brug for år, område
            urlNO = NO_(x, z)

            responseNO = requests.get(urlNO)
            htmlNO = responseNO.text
            jobindexNO = BeautifulSoup(htmlNO,'lxml')


            tal1NO = str(jobindexNO.find('h2'))
            if """<h2 class="search-title">""" in tal1NO:
                tal2NO = re.sub("""<h2 class="search-title">""", '', tal1NO)
                tal3NO = re.sub(""" job matcher din søgning</h2>""", '', tal2NO)
                tal4NO = int(tal3NO.replace('.',''))

# n_sektor_område:  brug for år, sektor, område
                for key in sektor:
                    urlNSO = NSO(key, x, z)

                    responseNSO = requests.get(urlNSO)
                    htmlNSO = responseNSO.text
                    jobindexNSO = BeautifulSoup(htmlNSO,'lxml')


                    tal1NSO = str(jobindexNSO.find('h2'))
                    if """<h2 class="search-title">""" in tal1NSO:
                        tal2NSO = re.sub("""<h2 class="search-title">""", '', tal1NSO)
                        tal3NSO = re.sub(""" job matcher din søgning</h2>""", '', tal2NSO)
                        tal4NSO = int(tal3NSO.replace('.',''))

# n_jobtype_område:  brug for år, sektor, område
                        for value in sektor[key]:
                            urlNJO = NJO(key, value, x, z)

                            responseNJO = requests.get(urlNJO)         # Opens link
                            htmlNJO = responseNJO.text
                            jobindexNJO = BeautifulSoup(htmlNJO,'lxml')


                            tal1NJO = str(jobindexNJO.find('h2'))                                          # Searching for tag 'h2' to locate wanted number
                            if """<h2 class="search-title">""" in tal1NJO:                                 # Checking if correct string is located
                                tal2NJO = re.sub("""<h2 class="search-title">""", '', tal1NJO)             # Removing first part of string
                                tal3NJO = re.sub(""" job matcher din søgning</h2>""", '', tal2NJO)         # Removing second part of string
                                tal4NJO = int(tal3NJO.replace('.',''))                                     # Removing dot and converting to integer


# Appending values to lists:    
                                n_jobtype_område_.append(tal4NJO)
                                n_sektor_område_.append(tal4NSO)
                                n_område_.append(tal4NO)
                                n_år_.append(tal4NÅ)


                                jobt_.append(value)
                                sektor_.append(key)
                                område_.append(x)
                                år_.append(z)

                                time.sleep(0.3)

# Appending lists to dataframe:
container0709 = pd.DataFrame(
    {'n_jobtype_area_': n_jobtype_område_,
     'n_year': n_år_,
     'n_sektor_area': n_sektor_område_,
     'n_area': n_område_,
     'jobtype': jobt_,
     'sektor': sektor_,
     'area': område_,
     'year': år_
    })

container0709.to_csv('con0709.csv')

# %%
# Kode til August:

år = [2010, 2011, 2012, 2013]

n_jobtype_område_ = []
n_sektor_område_ = []
n_område_ = []
n_år_ = []

jobt_ = []
sektor_ = []
område_ = []
år_ = []


# Running loop:

for z in år:
# n_år:  brug for år
    urlNÅ = NÅ(z)

    responseNÅ = requests.get(urlNÅ)
    htmlNÅ = responseNÅ.text
    jobindexNÅ = BeautifulSoup(htmlNÅ,'lxml')


    tal1NÅ = str(jobindexNÅ.find('h2'))
    if """<h2 class="search-title">""" in tal1NÅ:
        tal2NÅ = re.sub("""<h2 class="search-title">""", '', tal1NÅ)
        tal3NÅ = re.sub(""" job matcher din søgning</h2>""", '', tal2NÅ)
        tal4NÅ = int(tal3NÅ.replace('.',''))

        for x in område:
# n_område:  brug for år, område
            urlNO = NO_(x, z)

            responseNO = requests.get(urlNO)
            htmlNO = responseNO.text
            jobindexNO = BeautifulSoup(htmlNO,'lxml')


            tal1NO = str(jobindexNO.find('h2'))
            if """<h2 class="search-title">""" in tal1NO:
                tal2NO = re.sub("""<h2 class="search-title">""", '', tal1NO)
                tal3NO = re.sub(""" job matcher din søgning</h2>""", '', tal2NO)
                tal4NO = int(tal3NO.replace('.',''))

# n_sektor_område:  brug for år, sektor, område
                for key in sektor:
                    urlNSO = NSO(key, x, z)

                    responseNSO = requests.get(urlNSO)
                    htmlNSO = responseNSO.text
                    jobindexNSO = BeautifulSoup(htmlNSO,'lxml')


                    tal1NSO = str(jobindexNSO.find('h2'))
                    if """<h2 class="search-title">""" in tal1NSO:
                        tal2NSO = re.sub("""<h2 class="search-title">""", '', tal1NSO)
                        tal3NSO = re.sub(""" job matcher din søgning</h2>""", '', tal2NSO)
                        tal4NSO = int(tal3NSO.replace('.',''))

# n_jobtype_område:  brug for år, sektor, område
                        for value in sektor[key]:
                            urlNJO = NJO(key, value, x, z)

                            responseNJO = requests.get(urlNJO)         # Opens link
                            htmlNJO = responseNJO.text
                            jobindexNJO = BeautifulSoup(htmlNJO,'lxml')


                            tal1NJO = str(jobindexNJO.find('h2'))                                          # Searching for tag 'h2' to locate wanted number
                            if """<h2 class="search-title">""" in tal1NJO:                                 # Checking if correct string is located
                                tal2NJO = re.sub("""<h2 class="search-title">""", '', tal1NJO)             # Removing first part of string
                                tal3NJO = re.sub(""" job matcher din søgning</h2>""", '', tal2NJO)         # Removing second part of string
                                tal4NJO = int(tal3NJO.replace('.',''))                                     # Removing dot and converting to integer


# Appending values to lists:    
                                n_jobtype_område_.append(tal4NJO)
                                n_sektor_område_.append(tal4NSO)
                                n_område_.append(tal4NO)
                                n_år_.append(tal4NÅ)


                                jobt_.append(value)
                                sektor_.append(key)
                                område_.append(x)
                                år_.append(z)

                                time.sleep(0.3)

# Appending lists to dataframe:
container1013 = pd.DataFrame(
    {'n_jobtype_area_': n_jobtype_område_,
     'n_year': n_år_,
     'n_sektor_area': n_sektor_område_,
     'n_area': n_område_,
     'jobtype': jobt_,
     'sektor': sektor_,
     'area': område_,
     'year': år_
    })

container1013.to_csv('con1013.csv')

# %%
# Out:
#                 area               jobtype  n_area  n_jobtype_area_  \
# 0     storkoebenhavn              database   59463              265
# 1     storkoebenhavn               itdrift   59463             1446
# 2     storkoebenhavn              itkurser   59463                0
# 3     storkoebenhavn             itledelse   59463             1909
# 4     storkoebenhavn              internet   59463              504
# 5     storkoebenhavn       systemudvikling   59463             4087
# 6     storkoebenhavn               telekom   59463              111
# 7     storkoebenhavn   virksomhedssystemer   59463              734
# 8     storkoebenhavn           byggeteknik   59463              925
# 9     storkoebenhavn            elektronik   59463              561
# 10    storkoebenhavn                  kemi   59463             1214
# 11    storkoebenhavn         teknikledelse   59463              470
# 12    storkoebenhavn       maskiningenioer   59463              618
# 13    storkoebenhavn             medicinal   59463              626
# 14    storkoebenhavn     produktionsteknik   59463              723
# 15    storkoebenhavn         detailledelse   59463                0
# 16    storkoebenhavn    freelancekonsulent   59463              283
# 17    storkoebenhavn              hrkurser   59463                2
# 18    storkoebenhavn             itledelse   59463             1909
# 19    storkoebenhavn          institutions   59463              428
# 20    storkoebenhavn                 leder   59463             2288
# 21    storkoebenhavn         teknikledelse   59463              470
# 22    storkoebenhavn             personale   59463              777
# 23    storkoebenhavn        projektledelse   59463             1742
# 24    storkoebenhavn             salgschef   59463              751
# 25    storkoebenhavn            topledelse   59463              110
# 26    storkoebenhavn  virksomhedsudvikling   59463                0
# 27    storkoebenhavn          oekonomichef   59463              322
# 28    storkoebenhavn                   bud   59463               46
# 29    storkoebenhavn         boernepasning   59463              113
# ...              ...                   ...     ...              ...
# 4106         danmark              paedagog  188602            13045
# 4107         danmark             akademisk  188602                0
# 4108         danmark       ejendomsmaegler  188602              484
# 4109         danmark       ejendomsservice  188602              784
# 4110         danmark                finans  188602             3528
# 4111         danmark               indkoeb  188602             1548
# 4112         danmark                  jura  188602             1578
# 4113         danmark                kontor  188602             8964
# 4114         danmark          kontorkurser  188602              108
# 4115         danmark            kontorelev  188602             1240
# 4116         danmark              logistik  188602             1981
# 4117         danmark             offentlig  188602             2655
# 4118         danmark         oversaettelse  188602              569
# 4119         danmark             sekretaer  188602             1950
# 4120         danmark              oekonomi  188602             8479
# 4121         danmark                 laege  188602             4582
# 4122         danmark        laegesekretaer  188602             1793
# 4123         danmark                 pleje  188602             8814
# 4124         danmark             psykologi  188602             1314
# 4125         danmark     socialraadgivning  188602             2205
# 4126         danmark             tandlaege  188602              853
# 4127         danmark        teknisksundhed  188602              394
# 4128         danmark                terapi  188602             1756
# 4129         danmark                  elev  188602             3345
# 4130         danmark               forsvar  188602                0
# 4131         danmark            frivilligt  188602             4930
# 4132         danmark               student  188602             5697
# 4133         danmark         studiepraktik  188602             2388
# 4134         danmark               oevrige  188602             7511
# 4135         danmark         kurseroevrige  188602               80
#
#       n_sektor_area  n_year        sektor  year
# 0              7990  172785            it  2010
# 1              7990  172785            it  2010
# 2              7990  172785            it  2010
# 3              7990  172785            it  2010
# 4              7990  172785            it  2010
# 5              7990  172785            it  2010
# 6              7990  172785            it  2010
# 7              7990  172785            it  2010
# 8              4174  172785     ingenioer  2010
# 9              4174  172785     ingenioer  2010
# 10             4174  172785     ingenioer  2010
# 11             4174  172785     ingenioer  2010
# 12             4174  172785     ingenioer  2010
# 13             4174  172785     ingenioer  2010
# 14             4174  172785     ingenioer  2010
# 15             8302  172785       ledelse  2010
# 16             8302  172785       ledelse  2010
# 17             8302  172785       ledelse  2010
# 18             8302  172785       ledelse  2010
# 19             8302  172785       ledelse  2010
# 20             8302  172785       ledelse  2010
# 21             8302  172785       ledelse  2010
# 22             8302  172785       ledelse  2010
# 23             8302  172785       ledelse  2010
# 24             8302  172785       ledelse  2010
# 25             8302  172785       ledelse  2010
# 26             8302  172785       ledelse  2010
# 27             8302  172785       ledelse  2010
# 28             9011  172785        handel  2010
# 29             9011  172785        handel  2010
# ...             ...     ...           ...   ...
# 4106          28661  224151  undervisning  2013
# 4107          30946  224151        kontor  2013
# 4108          30946  224151        kontor  2013
# 4109          30946  224151        kontor  2013
# 4110          30946  224151        kontor  2013
# 4111          30946  224151        kontor  2013
# 4112          30946  224151        kontor  2013
# 4113          30946  224151        kontor  2013
# 4114          30946  224151        kontor  2013
# 4115          30946  224151        kontor  2013
# 4116          30946  224151        kontor  2013
# 4117          30946  224151        kontor  2013
# 4118          30946  224151        kontor  2013
# 4119          30946  224151        kontor  2013
# 4120          30946  224151        kontor  2013
# 4121          31269  224151        social  2013
# 4122          31269  224151        social  2013
# 4123          31269  224151        social  2013
# 4124          31269  224151        social  2013
# 4125          31269  224151        social  2013
# 4126          31269  224151        social  2013
# 4127          31269  224151        social  2013
# 4128          31269  224151        social  2013
# 4129          25032  224151       oevrige  2013
# 4130          25032  224151       oevrige  2013
# 4131          25032  224151       oevrige  2013
# 4132          25032  224151       oevrige  2013
# 4133          25032  224151       oevrige  2013
# 4134          25032  224151       oevrige  2013
# 4135          25032  224151       oevrige  2013
#
# [4136 rows x 8 columns]

# %%
# Kode til Nikolaj

år = [2014, 2015, 2016, 2017]

n_jobtype_område_ = []
n_sektor_område_ = []
n_område_ = []
n_år_ = []

jobt_ = []
sektor_ = []
område_ = []
år_ = []


# Running loop:

for z in år:
# n_år:  brug for år
    urlNÅ = NÅ(z)

    responseNÅ = requests.get(urlNÅ)
    htmlNÅ = responseNÅ.text
    jobindexNÅ = BeautifulSoup(htmlNÅ,'lxml')


    tal1NÅ = str(jobindexNÅ.find('h2'))
    if """<h2 class="search-title">""" in tal1NÅ:
        tal2NÅ = re.sub("""<h2 class="search-title">""", '', tal1NÅ)
        tal3NÅ = re.sub(""" job matcher din søgning</h2>""", '', tal2NÅ)
        tal4NÅ = int(tal3NÅ.replace('.',''))

        for x in område:
# n_område:  brug for år, område
            urlNO = NO_(x, z)

            responseNO = requests.get(urlNO)
            htmlNO = responseNO.text
            jobindexNO = BeautifulSoup(htmlNO,'lxml')


            tal1NO = str(jobindexNO.find('h2'))
            if """<h2 class="search-title">""" in tal1NO:
                tal2NO = re.sub("""<h2 class="search-title">""", '', tal1NO)
                tal3NO = re.sub(""" job matcher din søgning</h2>""", '', tal2NO)
                tal4NO = int(tal3NO.replace('.',''))

# n_sektor_område:  brug for år, sektor, område
                for key in sektor:
                    urlNSO = NSO(key, x, z)

                    responseNSO = requests.get(urlNSO)
                    htmlNSO = responseNSO.text
                    jobindexNSO = BeautifulSoup(htmlNSO,'lxml')


                    tal1NSO = str(jobindexNSO.find('h2'))
                    if """<h2 class="search-title">""" in tal1NSO:
                        tal2NSO = re.sub("""<h2 class="search-title">""", '', tal1NSO)
                        tal3NSO = re.sub(""" job matcher din søgning</h2>""", '', tal2NSO)
                        tal4NSO = int(tal3NSO.replace('.',''))

# n_jobtype_område:  brug for år, sektor, område
                        for value in sektor[key]:
                            urlNJO = NJO(key, value, x, z)

                            responseNJO = requests.get(urlNJO)         # Opens link
                            htmlNJO = responseNJO.text
                            jobindexNJO = BeautifulSoup(htmlNJO,'lxml')


                            tal1NJO = str(jobindexNJO.find('h2'))                                          # Searching for tag 'h2' to locate wanted number
                            if """<h2 class="search-title">""" in tal1NJO:                                 # Checking if correct string is located
                                tal2NJO = re.sub("""<h2 class="search-title">""", '', tal1NJO)             # Removing first part of string
                                tal3NJO = re.sub(""" job matcher din søgning</h2>""", '', tal2NJO)         # Removing second part of string
                                tal4NJO = int(tal3NJO.replace('.',''))                                     # Removing dot and converting to integer


# Appending values to lists:    
                                n_jobtype_område_.append(tal4NJO)
                                n_sektor_område_.append(tal4NSO)
                                n_område_.append(tal4NO)
                                n_år_.append(tal4NÅ)


                                jobt_.append(value)
                                sektor_.append(key)
                                område_.append(x)
                                år_.append(z)

                                time.sleep(0.3)

# Appending lists to dataframe:
container1417 = pd.DataFrame(
    {'n_jobtype_area_': n_jobtype_område_,
     'n_year': n_år_,
     'n_sektor_area': n_sektor_område_,
     'n_area': n_område_,
     'jobtype': jobt_,
     'sektor': sektor_,
     'area': område_,
     'year': år_
    })

container1417.to_csv('con1417.csv')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse(buffering=True)
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-35-3f3adf013a18>", line 67, in <module>
#     responseNJO = requests.get(urlNJO)         # Opens link
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\requests\api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\requests\api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\requests\sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\requests\sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\requests\adapters.py", line 440, in send
#     timeout=timeout
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 383, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\nimbu\Anaconda3\lib\http\client.py", line 1331, in getresponse
#     response.begin()
#   File "C:\Users\nimbu\Anaconda3\lib\http\client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\nimbu\Anaconda3\lib\http\client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\nimbu\Anaconda3\lib\socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 280, in recv_into
#     return self.connection.recv_into(*args, **kwargs)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1813, in recv_into
#     result = _lib.SSL_read(self._ssl, buf, nbytes)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\nimbu\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\nimbu\Anaconda3\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\nimbu\Anaconda3\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\nimbu\Anaconda3\lib\inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\nimbu\Anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_code(self, code_obj, result)
#    2962                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2963                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2964             finally:
#
# <ipython-input-35-3f3adf013a18> in <module>()
#      66
# ---> 67                             responseNJO = requests.get(urlNJO)         # Opens link
#      68                             htmlNJO = responseNJO.text
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1862                         # in the engines. This should return a list of strings.
# -> 1863                         stb = value._render_traceback_()
#    1864                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_code(self, code_obj, result)
#    2978             if result is not None:
#    2979                 result.error_in_exec = sys.exc_info()[1]
# -> 2980             self.showtraceback(running_compiled_code=True)
#    2981         else:
#    2982             outflag = False
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1864                     except Exception:
#    1865                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1866                                             value, tb, tb_offset=tb_offset)
#    1867
#    1868                     self._showtraceback(etype, value, stb)
#
# ~\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1371         self.tb = tb
#    1372         return FormattedTB.structured_traceback(
# -> 1373             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1374
#    1375
#
# ~\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1279             # Verbose modes need a full traceback
#    1280             return VerboseTB.structured_traceback(
# -> 1281                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1282             )
#    1283         else:
#
# ~\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1142         exception = self.get_parts_of_chained_exception(evalue)
#    1143         if exception:
# -> 1144             formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1145             etype, evalue, etb = exception
#    1146         else:
#
# TypeError: must be str, not list

# %%
# Out:
# 8

# %%
contest = container1417.copy()

# %%
container1417
# Out:
#     n_jobtype_area_  n_year  n_sektor_area  n_area               jobtype  \
# 0               437  255002          11987   98423              database
# 1              2221  255002          11987   98423               itdrift
# 2               205  255002          11987   98423              itkurser
# 3              1283  255002          11987   98423             itledelse
# 4               889  255002          11987   98423              internet
# 5              7288  255002          11987   98423       systemudvikling
# 6               173  255002          11987   98423               telekom
# 7              1546  255002          11987   98423   virksomhedssystemer
# 8              1765  255002           8475   98423           byggeteknik
# 9              1019  255002           8475   98423            elektronik
# 10             2395  255002           8475   98423                  kemi
# 11              843  255002           8475   98423         teknikledelse
# 12             1490  255002           8475   98423       maskiningenioer
# 13             1777  255002           8475   98423             medicinal
# 14             1887  255002           8475   98423     produktionsteknik
# 15                0  255002          10849   98423         detailledelse
# 16              192  255002          10849   98423    freelancekonsulent
# 17              178  255002          10849   98423              hrkurser
# 18             1283  255002          10849   98423             itledelse
# 19              592  255002          10849   98423          institutions
# 20             2511  255002          10849   98423                 leder
# 21              843  255002          10849   98423         teknikledelse
# 22             1222  255002          10849   98423             personale
# 23             3805  255002          10849   98423        projektledelse
# 24              811  255002          10849   98423             salgschef
# 25              192  255002          10849   98423            topledelse
# 26                0  255002          10849   98423  virksomhedsudvikling
# 27              347  255002          10849   98423          oekonomichef
# 28               33  255002           1083   16754              database
# 29              196  255002           1083   16754               itdrift
# ..              ...     ...            ...     ...                   ...
# 54                0  255002           1557   16754  virksomhedsudvikling
# 55               41  255002           1557   16754          oekonomichef
# 56               29  255002            647   23507              database
# 57              201  255002            647   23507               itdrift
# 58                1  255002            647   23507              itkurser
# 59               54  255002            647   23507             itledelse
# 60               56  255002            647   23507              internet
# 61              341  255002            647   23507       systemudvikling
# 62               11  255002            647   23507               telekom
# 63               63  255002            647   23507   virksomhedssystemer
# 64              423  255002           2005   23507           byggeteknik
# 65              209  255002           2005   23507            elektronik
# 66              576  255002           2005   23507                  kemi
# 67              206  255002           2005   23507         teknikledelse
# 68              395  255002           2005   23507       maskiningenioer
# 69              349  255002           2005   23507             medicinal
# 70              516  255002           2005   23507     produktionsteknik
# 71                0  255002           1848   23507         detailledelse
# 72               58  255002           1848   23507    freelancekonsulent
# 73               24  255002           1848   23507              hrkurser
# 74               54  255002           1848   23507             itledelse
# 75              342  255002           1848   23507          institutions
# 76              566  255002           1848   23507                 leder
# 77              206  255002           1848   23507         teknikledelse
# 78              150  255002           1848   23507             personale
# 79              415  255002           1848   23507        projektledelse
# 80               98  255002           1848   23507             salgschef
# 81               29  255002           1848   23507            topledelse
# 82                0  255002           1848   23507  virksomhedsudvikling
# 83               40  255002           1848   23507          oekonomichef
#
#        sektor              area  year
# 0          it    storkoebenhavn  2014
# 1          it    storkoebenhavn  2014
# 2          it    storkoebenhavn  2014
# 3          it    storkoebenhavn  2014
# 4          it    storkoebenhavn  2014
# 5          it    storkoebenhavn  2014
# 6          it    storkoebenhavn  2014
# 7          it    storkoebenhavn  2014
# 8   ingenioer    storkoebenhavn  2014
# 9   ingenioer    storkoebenhavn  2014
# 10  ingenioer    storkoebenhavn  2014
# 11  ingenioer    storkoebenhavn  2014
# 12  ingenioer    storkoebenhavn  2014
# 13  ingenioer    storkoebenhavn  2014
# 14  ingenioer    storkoebenhavn  2014
# 15    ledelse    storkoebenhavn  2014
# 16    ledelse    storkoebenhavn  2014
# 17    ledelse    storkoebenhavn  2014
# 18    ledelse    storkoebenhavn  2014
# 19    ledelse    storkoebenhavn  2014
# 20    ledelse    storkoebenhavn  2014
# 21    ledelse    storkoebenhavn  2014
# 22    ledelse    storkoebenhavn  2014
# 23    ledelse    storkoebenhavn  2014
# 24    ledelse    storkoebenhavn  2014
# 25    ledelse    storkoebenhavn  2014
# 26    ledelse    storkoebenhavn  2014
# 27    ledelse    storkoebenhavn  2014
# 28         it     nordsjaelland  2014
# 29         it     nordsjaelland  2014
# ..        ...               ...   ...
# 54    ledelse     nordsjaelland  2014
# 55    ledelse     nordsjaelland  2014
# 56         it  region-sjaelland  2014
# 57         it  region-sjaelland  2014
# 58         it  region-sjaelland  2014
# 59         it  region-sjaelland  2014
# 60         it  region-sjaelland  2014
# 61         it  region-sjaelland  2014
# 62         it  region-sjaelland  2014
# 63         it  region-sjaelland  2014
# 64  ingenioer  region-sjaelland  2014
# 65  ingenioer  region-sjaelland  2014
# 66  ingenioer  region-sjaelland  2014
# 67  ingenioer  region-sjaelland  2014
# 68  ingenioer  region-sjaelland  2014
# 69  ingenioer  region-sjaelland  2014
# 70  ingenioer  region-sjaelland  2014
# 71    ledelse  region-sjaelland  2014
# 72    ledelse  region-sjaelland  2014
# 73    ledelse  region-sjaelland  2014
# 74    ledelse  region-sjaelland  2014
# 75    ledelse  region-sjaelland  2014
# 76    ledelse  region-sjaelland  2014
# 77    ledelse  region-sjaelland  2014
# 78    ledelse  region-sjaelland  2014
# 79    ledelse  region-sjaelland  2014
# 80    ledelse  region-sjaelland  2014
# 81    ledelse  region-sjaelland  2014
# 82    ledelse  region-sjaelland  2014
# 83    ledelse  region-sjaelland  2014
#
# [84 rows x 8 columns]

# %%
df_new = pd.read_csv('con1417.csv')
writer = pd.ExcelWriter('test.xlsx')
df_new.to_excel(writer, index = False)
writer.save()

# %%
# Hent data for n_sektor: 

n_sektor_1 = []

for z in år:
# n_år:  brug for år
    urlNÅ = NÅ(z)

    responseNÅ = requests.get(urlNÅ)
    htmlNÅ = responseNÅ.text
    jobindexNÅ = BeautifulSoup(htmlNÅ,'lxml')


    tal1NÅ = str(jobindexNÅ.find('h2'))
    if """<h2 class="search-title">""" in tal1NÅ:
        tal2NÅ = re.sub("""<h2 class="search-title">""", '', tal1NÅ)
        tal3NÅ = re.sub(""" job matcher din søgning</h2>""", '', tal2NÅ)
        tal4NÅ = int(tal3NÅ.replace('.',''))

# n_sektor:  brug for år, sektor
        for key in sektor:
            urlNS = NS(key, z)

            responseNS = requests.get(urlNS)
            htmlNS = responseNS.text
            jobindexNS = BeautifulSoup(htmlNS,'lxml')


            tal1NS = str(jobindexNS.find('h2'))
            if """<h2 class="search-title">""" in tal1NS:
                tal2NS = re.sub("""<h2 class="search-title">""", '', tal1NS)
                tal3NS = re.sub(""" job matcher din søgning</h2>""", '', tal2NS)
                tal4NS = int(tal3NS.replace('.',''))
        
                n_sektor_1.append(tal4NS)
            
n_sektor_1
